# %% [markdown]
# # Conclusions
#
# I think a tool like this could be a very useful addition at some point, especially for profiling plugin performance. It would be possible to extend this to provide rough profiling (for instance be allowing for 'notes' to be attached to traces) but that might be overkill. It's more useful to think of this as a diagnostics tool, and when particular slowness is encountered heavier profiling tools can be brought to bear.
#
# ## Pain points
#
# Threading trace IDs through the call graph is a pain. Much of this is dependent on how multi-threaded we are, and on various unnecessary convolutions in our graph itself.
#
# ## Alternative designs
#
# The current design is fairly simple: each process checks incoming messages for the existence of a `trace_id` field, and if it exists that process begins sending timestamps as well. When it receives a message with no `trace_id` field, it stops sending them.
#
# In the client, we begin tracing by just adding that field to our messages.
#
# When we want to _collect_ traces, we have a special RPC `xi-rpc.collect_traces`, which we send out to all peers; they respond with whatever traces they've collected. This is annoying, becuase we have to propogate this call up through the handler to each plugin process.
#
# Ideally we would have some mechanism by which peers automatically returned traces periodically, and then we would stash them in some global repository.
#
# ### Always on / autosend?
# At least at the RPC level, it should be possible to implement very efficient tracing, taking advantage of the idle scheduler.
#
# - _all_ RPCs would get a timestamp
# - each runloop would maintain a thread-local array of traces
# - if ever the idle checker fired and found no tasks, the process would send its accumulated traces to its peer (this assumes some mechanism whereby a process knows whether or not it is a client or not)
# - core aggregates traces, discarding them if they aren't needed.
#
# This could be done without a lot of overhead.

# %%
import os
import json
from collections import namedtuple, Counter, defaultdict
from operator import attrgetter

# %%
class Trace(object):
    def __init__(self, label, parent, proc_name, timestamp):
        self.label = label
        self.parent_time = parent
        self.proc_name = proc_name
        self.timestamp = timestamp
        self.children = []
        self.ident = -1
        self.delta_t = 0
        self.num_ancestors = -1
        self.parent = None
        

    def __str__(self):
        return "{:12} -> {:<12} (+{:>10.2f}µs) {}.{}".format(self.parent_time, self.timestamp, self.delta_t / 1000, self.proc_name, self.label)
        
    def __repr__(self):
        return "{}:".format(self.ident) + str(self)
    
    def group_print(self, level=0):
        fstr = "{}{:<%s}{}" % (12 - level,)
        print(fstr.format(' ' * level, str(self.ident) + ':', str(self)))
        level += 1
        for child in self.children:
            child.group_print(level)

# %%
trace_file = './trace_load_jq.json'

# %%
traces = json.load(open(trace_file))
traces = [Trace(t['label'], t['parent'], t['proc_name'], t['timestamp']) for t in traces]

min_t = min(t.timestamp for t in traces)
traces.sort(key=attrgetter('timestamp'))

# the last item is the trace request
traces.pop()

for (i, t) in enumerate(traces):
    t.ident = i + 1
    t.timestamp = max(0, t.timestamp - min_t + 1)
    t.parent_time = max(0, t.parent_time - min_t + 1)
    if i > 0:
        t.delta_t = t.timestamp - traces[i-1].timestamp

# %%
len_t = len(traces)

print("loaded {} traces from {}".format(len_t, set(t.proc_name for t in traces)))

set_t = set(t.timestamp for t in traces)
if len(set_t) != len_t:
    print("found duplicate traces")
    print(Counter(traces).most_common())
for t in traces[:10]:
    print(t)
# Out:
# loaded 12839 traces from {'xi-host.syntect', 'xi-mac', 'xi-core', 'syntect'}
#            0 -> 1            (+      0.00µs) xi-mac.send.client_started
#            0 -> 906929       (+    906.93µs) xi-mac.send.set_theme
#            0 -> 224295843    (+ 223388.91µs) xi-mac.send.new_view
#            0 -> 329489619    (+ 105193.78µs) xi-mac.send.new_view
#            0 -> 330208271    (+    718.65µs) xi-mac.send.new_view
#            1 -> 373552796    (+  43344.53µs) xi-core.recv.client_started
#    373552796 -> 380374599    (+   6821.80µs) xi-core.send.available_themes
#       906929 -> 380583042    (+    208.44µs) xi-core.recv.set_theme
#    380374599 -> 381033159    (+    450.12µs) xi-mac.recv.available_themes
#    380583042 -> 382874127    (+   1840.97µs) xi-core.send.theme_changed

# %% [markdown]
# ## Making some sense of data
#
# What can we do with these?
#
# 1. Causality trees: each event has a maximum of 1 parent.
# 2. classify like event chains: how many distinct patterns of messages are there?
# 3. classify event pairs; show their average times

# %%
def call_trees(traces):
    child_counts = Counter([t.parent_time for t in traces])
    grouped_traces = {t.timestamp: t for t in traces}

    while True:
        childless = [t for (i, t) in grouped_traces.items() if t.parent_time != 0 and child_counts.get(i, 0) <= 0]
        orphans = [t for t in childless if t.parent_time not in grouped_traces]
        for o in orphans:
            print("removing orphan %s" % o)
            childless.remove(o)
            del grouped_traces[o.timestamp]
#         assert not len(orphans), '\n'.join(str(o) for o in orphans)
        if len(childless) == 0:
            break
        for trace in childless:
            del grouped_traces[trace.timestamp]
            grouped_traces[trace.parent_time].children.append(trace)
            trace.parent = grouped_traces[trace.parent_time]
            trace.delta_t = trace.timestamp - trace.parent.timestamp
            child_counts[trace.parent_time] -= 1

    grouped = list(grouped_traces.values())
    for g in grouped:
        g.num_ancestors = num_ancestors(g)
    return grouped

def num_ancestors(node):
    if not len(node.children):
        return 1
    else:
        return 1 + sum(num_ancestors(c) for c in node.children)

def group_print(call, level=0):
    if level == 0:
        elapsed = max_child_time(call) - call.timestamp
        print('total elapsed: {:.2f}µs'.format(elapsed/1000))

    fstr = "{}{:<%s}{}" % (12 - level,)
    print(fstr.format(' ' * level, str(call.ident) + ':', str(call)))
    level += 1
    for child in call.children:
        child.group_print(level)

        
def max_child_time(node):
    if not len(node.children):
        return node.timestamp
    else:
        return max([max_child_time(c) for c in node.children])

# %%
calls = call_trees(traces)
# Out:
# removing orphan 316438380745 -> 316438585062 (+18230293.60µs) syntect.recv.xi-rpc.collect_traces
# removing orphan   1738782040 -> 1977746928   (+   3594.40µs) xi-core.send.update
# removing orphan   1738782040 -> 1981538167   (+   2129.21µs) xi-core.send.def_style
# removing orphan   1738782040 -> 1981969791   (+    239.73µs) xi-core.send.def_style
# removing orphan   1738782040 -> 1982093653   (+    123.86µs) xi-core.send.def_style
# removing orphan   1738782040 -> 1983025039   (+    774.03µs) xi-core.send.def_style
# removing orphan   2028797727 -> 2179353441   (+   6626.85µs) xi-core.send.update
# removing orphan   2435826765 -> 2721618489   (+   6292.44µs) xi-core.send.update
# removing orphan   2800490754 -> 3004880916   (+   6380.43µs) xi-core.send.update
# removing orphan   3114434149 -> 4114060479   (+   1269.02µs) xi-core.send.update
# removing orphan   4124000162 -> 4136453003   (+    534.03µs) xi-core.send.update
# removing orphan   4717258087 -> 4728519565   (+   1094.90µs) xi-core.send.update
# removing orphan   4808880441 -> 5257012890   (+   1083.17µs) xi-core.send.update
# removing orphan   5267584626 -> 5287505183   (+   1717.66µs) xi-core.send.update
# removing orphan   5330266949 -> 5659918349   (+   2103.72µs) xi-core.send.update
# removing orphan   5670482374 -> 5683583946   (+   2799.55µs) xi-core.send.update
# removing orphan   6171413766 -> 6529532883   (+   3100.96µs) xi-core.send.update
# removing orphan   6540964269 -> 6554982514   (+   3406.34µs) xi-core.send.update
# removing orphan   7311861535 -> 7326615152   (+   3794.17µs) xi-core.send.update
# removing orphan   7351607641 -> 7685854367   (+   4056.43µs) xi-core.send.update
# removing orphan   7697651873 -> 7713391221   (+   4069.18µs) xi-core.send.update
# removing orphan   7807742485 -> 8025606874   (+   3960.72µs) xi-core.send.update
# removing orphan   8037117606 -> 8052938219   (+   4511.77µs) xi-core.send.update
# removing orphan   8377750518 -> 8670919749   (+   4899.97µs) xi-core.send.update
# removing orphan   8682179765 -> 8699456084   (+   5239.54µs) xi-core.send.update
# removing orphan   8799602821 -> 9387994014   (+   4873.55µs) xi-core.send.update
# removing orphan   9399982043 -> 9418815154   (+    440.86µs) xi-core.send.update
# removing orphan   9479053459 -> 10890672134  (+   5145.02µs) xi-core.send.update
# removing orphan  10902367925 -> 10918738598  (+   4852.49µs) xi-core.send.update
# removing orphan  11093128635 -> 12236339732  (+   8667.45µs) xi-core.send.update
# removing orphan  12249555545 -> 12278402926  (+   5819.57µs) xi-core.send.update
# removing orphan  12344384790 -> 12869829292  (+   4996.22µs) xi-core.send.update
# removing orphan  12882804434 -> 12902032096  (+   6520.24µs) xi-core.send.update
# removing orphan  13021759115 -> 13351234096  (+   4238.93µs) xi-core.send.update
# removing orphan  13362350912 -> 13385556449  (+   5059.93µs) xi-core.send.update
# removing orphan  13401134721 -> 14190135292  (+   4454.04µs) xi-core.send.update
# removing orphan  14201802750 -> 14229817669  (+  10037.76µs) xi-core.send.update
# removing orphan  14251180246 -> 14377151834  (+   4513.96µs) xi-core.send.update
# removing orphan  14388334681 -> 14411339257  (+   5904.94µs) xi-core.send.update
# removing orphan  14471908078 -> 15106479806  (+   5067.11µs) xi-core.send.update
# removing orphan  15119172377 -> 15143136097  (+   6112.28µs) xi-core.send.update
# removing orphan  15150175751 -> 15544794543  (+   5114.12µs) xi-core.send.update
# removing orphan  15565311798 -> 15589304856  (+   5704.49µs) xi-core.send.update
# removing orphan  15623490990 -> 16061073959  (+   5142.37µs) xi-core.send.update
# removing orphan  16074237302 -> 16098475291  (+   5400.83µs) xi-core.send.update
# removing orphan  16115056789 -> 16249830131  (+   4621.43µs) xi-core.send.update
# removing orphan  16261942145 -> 16298187511  (+   9645.14µs) xi-core.send.update
# removing orphan  16838684805 -> 17034910804  (+   3745.77µs) xi-core.send.update
# removing orphan  17047239250 -> 17065991324  (+   3517.27µs) xi-core.send.update
# removing orphan  17439646572 -> 17750199867  (+   3185.62µs) xi-core.send.update
# removing orphan  17763859883 -> 17781469439  (+   3327.05µs) xi-core.send.update
# removing orphan  17863767295 -> 18085165729  (+   1849.39µs) xi-core.send.update
# removing orphan  18096795282 -> 18114221247  (+   2685.16µs) xi-core.send.update
# removing orphan  18136364262 -> 18450765075  (+   2275.41µs) xi-core.send.update
# removing orphan  18462301213 -> 18478166125  (+   2132.67µs) xi-core.send.update
# removing orphan  18562185300 -> 18827744452  (+   1260.80µs) xi-core.send.update
# removing orphan  18839241667 -> 18863401702  (+    573.58µs) xi-core.send.update
# removing orphan  18868565716 -> 19202062910  (+   1214.40µs) xi-core.send.update
# removing orphan  19213613713 -> 19231737534  (+   1014.33µs) xi-core.send.update
# removing orphan  19270265599 -> 20008319329  (+   1050.11µs) xi-core.send.update
# removing orphan  20351301342 -> 21138842479  (+    895.19µs) xi-core.send.update
# removing orphan  21151065298 -> 21169000580  (+   1514.15µs) xi-core.send.update
# removing orphan  21245353213 -> 22191683039  (+    516.99µs) xi-core.send.update
# removing orphan  22202134390 -> 22216380794  (+    443.89µs) xi-core.send.update
# removing orphan  22226993255 -> 23825358559  (+   1278.72µs) xi-core.send.update
# removing orphan  23835579547 -> 23850446959  (+   1663.92µs) xi-core.send.update
# removing orphan  23909787015 -> 24817882422  (+   1024.22µs) xi-core.send.update
# removing orphan  24828805611 -> 24842920920  (+    868.67µs) xi-core.send.update
# removing orphan  24852565696 -> 26168963437  (+   1111.64µs) xi-core.send.update
# removing orphan  26173941523 -> 26191683508  (+    853.09µs) xi-core.send.update
# removing orphan  26203043276 -> 26803652784  (+    567.67µs) xi-core.send.update
# removing orphan  26856025275 -> 26877611119  (+   1013.07µs) xi-core.send.update
# removing orphan  27166206655 -> 27186451268  (+    719.46µs) xi-core.send.update
# removing orphan  27233438639 -> 27403440123  (+   1118.01µs) xi-core.send.update
# removing orphan  27414072565 -> 27418988147  (+   1625.35µs) xi-core.send.update
# removing orphan  27451492973 -> 27474017214  (+   1053.38µs) xi-core.send.update
# removing orphan  27483945768 -> 28065430314  (+    487.70µs) xi-core.send.update
# removing orphan  28102577560 -> 28120258375  (+   1174.31µs) xi-core.send.update
# removing orphan  28131254454 -> 28661072737  (+    753.77µs) xi-core.send.update
# removing orphan  28799009322 -> 28818996674  (+   5512.53µs) xi-core.send.update
# removing orphan  28830968211 -> 29518550606  (+   5005.97µs) xi-core.send.update
# removing orphan  29572849299 -> 29594526264  (+   5661.96µs) xi-core.send.update
# removing orphan  29605745205 -> 29958572270  (+   5050.83µs) xi-core.send.update
# removing orphan  29969602106 -> 29988003314  (+   4233.94µs) xi-core.send.update
# removing orphan  30001324145 -> 31218956141  (+   4641.41µs) xi-core.send.update
# removing orphan  31629794402 -> 31647045079  (+   4512.70µs) xi-core.send.update
# removing orphan  31661187495 -> 32451181142  (+   4378.57µs) xi-core.send.update
# removing orphan  32501411955 -> 32526213984  (+   5398.18µs) xi-core.send.update
# removing orphan  32538789399 -> 33761973912  (+   5244.27µs) xi-core.send.update
# removing orphan  34050770967 -> 34062518904  (+    631.08µs) xi-core.send.update
# removing orphan  34071183739 -> 34840826749  (+    697.94µs) xi-core.send.update
# removing orphan  35070864878 -> 35088173722  (+    401.72µs) xi-core.send.update
# removing orphan  35100186710 -> 35604171510  (+    874.11µs) xi-core.send.update
# removing orphan  35982494144 -> 35994253710  (+    598.27µs) xi-core.send.update
# removing orphan  36006312028 -> 36301271104  (+    611.33µs) xi-core.send.update
# removing orphan  36387739488 -> 36402014014  (+   1785.88µs) xi-core.send.update
# removing orphan  36419114425 -> 37309375492  (+   1185.89µs) xi-core.send.update
# removing orphan  37340289422 -> 37356117860  (+    660.44µs) xi-core.send.update
# removing orphan  37366075825 -> 37973794078  (+    742.44µs) xi-core.send.update
# removing orphan  38131344961 -> 38431278610  (+    503.38µs) xi-core.send.update
# removing orphan  38492044865 -> 39251692394  (+    703.57µs) xi-core.send.update
# removing orphan  39276850398 -> 39295195494  (+   1149.73µs) xi-core.send.update
# removing orphan  39638542332 -> 40510697143  (+    510.66µs) xi-core.send.update
# removing orphan  40520509871 -> 40541636094  (+   2007.07µs) xi-core.send.update
# removing orphan  40677730230 -> 40761299865  (+   3786.18µs) xi-core.send.update
# removing orphan  40773878802 -> 40788707389  (+   5509.68µs) xi-core.send.update
# removing orphan  40798271299 -> 41399406533  (+   3320.75µs) xi-core.send.update
# removing orphan  41409591510 -> 41427050606  (+   2945.20µs) xi-core.send.update
# removing orphan  41474531213 -> 42011156884  (+   4414.04µs) xi-core.send.update
# removing orphan  42021175230 -> 42032963978  (+   1048.44µs) xi-core.send.update
# removing orphan  42047401961 -> 42152758271  (+   1232.05µs) xi-core.send.update
# removing orphan  42194742693 -> 42582858838  (+   2885.58µs) xi-core.send.update
# removing orphan  42591767548 -> 42607526636  (+   3289.80µs) xi-core.send.update
# removing orphan  42618922971 -> 42826027443  (+   3357.76µs) xi-core.send.update
# removing orphan  42835297214 -> 42855579662  (+   4496.60µs) xi-core.send.update
# removing orphan  42866246462 -> 43901090321  (+   5672.90µs) xi-core.send.update
# removing orphan  43911499151 -> 43928447894  (+   3320.34µs) xi-core.send.update
# removing orphan  43937077685 -> 44444083912  (+   4111.47µs) xi-core.send.update
# removing orphan  44457190634 -> 44472242861  (+   3455.55µs) xi-core.send.update
# removing orphan  44485078744 -> 44808473864  (+    615.43µs) xi-core.send.update
# removing orphan  44819566410 -> 44834536685  (+   1067.52µs) xi-core.send.update
# removing orphan  44898944162 -> 46549627753  (+    443.58µs) xi-core.send.update
# removing orphan  46559021360 -> 46572139065  (+   1208.08µs) xi-core.send.update
# removing orphan  46586702948 -> 47034344634  (+    615.80µs) xi-core.send.update
# removing orphan  47043749061 -> 47055992728  (+   1027.47µs) xi-core.send.update
# removing orphan  47117826317 -> 47348295316  (+    954.01µs) xi-core.send.update
# removing orphan  47357741701 -> 47368998565  (+    911.32µs) xi-core.send.update
# removing orphan  47671170609 -> 47773793059  (+    416.50µs) xi-core.send.update
# removing orphan  47783644700 -> 47796419954  (+    533.77µs) xi-core.send.update
# removing orphan  47968685082 -> 48273564184  (+    826.11µs) xi-core.send.update
# removing orphan  48322145964 -> 48723499617  (+    381.70µs) xi-core.send.update
# removing orphan  48733624591 -> 48741949020  (+    478.86µs) xi-core.send.update
# removing orphan  49106106446 -> 49117224915  (+    477.43µs) xi-core.send.update
# removing orphan  49122791735 -> 49429430890  (+    662.59µs) xi-core.send.update
# removing orphan  49616128831 -> 49894890018  (+    612.98µs) xi-core.send.update
# removing orphan  49904815272 -> 49916972701  (+    856.63µs) xi-core.send.update
# removing orphan  50442314383 -> 50636366966  (+    367.70µs) xi-core.send.update
# removing orphan  50645017035 -> 50656860549  (+    959.09µs) xi-core.send.update
# removing orphan  50955710332 -> 51848235089  (+   1199.85µs) xi-core.send.update
# removing orphan  51894536192 -> 52469065531  (+   1406.25µs) xi-core.send.update
# removing orphan  52481230261 -> 52491686588  (+   1028.84µs) xi-core.send.update
# removing orphan  52566136156 -> 53095031182  (+   1444.82µs) xi-core.send.update
# removing orphan  53104124228 -> 53115444650  (+    527.41µs) xi-core.send.update
# removing orphan  53129264230 -> 53392221377  (+    353.49µs) xi-core.send.update
# removing orphan  53401761080 -> 53416676430  (+   1441.07µs) xi-core.send.update
# removing orphan  53449892428 -> 53655531077  (+   1502.39µs) xi-core.send.update
# removing orphan  53665374660 -> 53682306900  (+   1124.45µs) xi-core.send.update
# removing orphan  53691455123 -> 53866864823  (+   1990.92µs) xi-core.send.update
# removing orphan  54019755672 -> 54033574504  (+   1005.73µs) xi-core.send.update
# removing orphan  54042453155 -> 54088470584  (+   1173.31µs) xi-core.send.update
# removing orphan  54306603850 -> 54317946638  (+    982.55µs) xi-core.send.update
# removing orphan  54329386331 -> 54681200484  (+   1201.32µs) xi-core.send.update
# removing orphan  54744531777 -> 54757978845  (+   1759.66µs) xi-core.send.update
# removing orphan  54768441031 -> 55202480616  (+   1393.55µs) xi-core.send.update
# removing orphan  55209670758 -> 55223526492  (+   1659.67µs) xi-core.send.update
# removing orphan  55233887678 -> 55887379667  (+   1405.27µs) xi-core.send.update
# removing orphan  55893152145 -> 55906520343  (+   1978.73µs) xi-core.send.update
# removing orphan  55917344963 -> 56275387302  (+  28146.62µs) xi-core.send.update
# removing orphan  56780401511 -> 56792883249  (+   2096.26µs) xi-core.send.update
# removing orphan  56802224520 -> 57068472054  (+   2713.43µs) xi-core.send.update
# removing orphan  57082149811 -> 57099785483  (+   2790.24µs) xi-core.send.update
# removing orphan  57210832505 -> 57494172725  (+   2082.32µs) xi-core.send.update
# removing orphan  57504693884 -> 57520346577  (+   2482.42µs) xi-core.send.update
# removing orphan  57531851137 -> 58051374227  (+    373.33µs) xi-core.send.update
# removing orphan  58060393457 -> 58072924450  (+    328.94µs) xi-core.send.update
# removing orphan  58345181130 -> 59148118941  (+    746.71µs) xi-core.send.update
# removing orphan  59175596148 -> 59432338889  (+    531.72µs) xi-core.send.update
# removing orphan  59441610936 -> 59456165797  (+    599.88µs) xi-core.send.update
# removing orphan  59466891741 -> 59604744620  (+    507.35µs) xi-core.send.update
# removing orphan  59614370372 -> 59628237163  (+    580.93µs) xi-core.send.update
# removing orphan  59650067261 -> 59836579351  (+    442.94µs) xi-core.send.update
# removing orphan  59862572989 -> 59931931610  (+   3101.95µs) xi-core.send.update
# removing orphan  59940459744 -> 59956204162  (+   3319.23µs) xi-core.send.update
# removing orphan  59967963548 -> 59984761840  (+   3228.80µs) xi-core.send.update
# removing orphan  59994121769 -> 60012482266  (+   3842.59µs) xi-core.send.update
# removing orphan  60024038998 -> 60776304910  (+   3262.84µs) xi-core.send.update
# removing orphan  60785383029 -> 60802658470  (+   3666.25µs) xi-core.send.update
# removing orphan  60809634403 -> 60905504421  (+   3034.44µs) xi-core.send.update
# removing orphan  60914665512 -> 60927283818  (+   4012.78µs) xi-core.send.update
# removing orphan  61038539186 -> 61202008727  (+   3285.72µs) xi-core.send.update
# removing orphan  61211164077 -> 61223459807  (+   3573.49µs) xi-core.send.update
# removing orphan  61230167162 -> 61265473607  (+   3179.93µs) xi-core.send.update
# removing orphan  61274460273 -> 61290892609  (+   4791.53µs) xi-core.send.update
# removing orphan  61295407990 -> 61472703197  (+   3535.95µs) xi-core.send.update
# removing orphan  61482381177 -> 61495400007  (+    886.30µs) xi-core.send.update
# removing orphan  61541064597 -> 61797023599  (+   3933.75µs) xi-core.send.update
# removing orphan  61806470521 -> 61818696271  (+   2962.89µs) xi-core.send.update
# removing orphan  61826976949 -> 62157956715  (+    483.52µs) xi-core.send.update
# removing orphan  62166393017 -> 62181116752  (+   2294.71µs) xi-core.send.update
# removing orphan  62186061611 -> 62821474026  (+    818.67µs) xi-core.send.update
# removing orphan  62833461383 -> 62854239082  (+   2037.56µs) xi-core.send.update
# removing orphan  62864409240 -> 63946188308  (+    961.79µs) xi-core.send.update
# removing orphan  63955504874 -> 63966635280  (+    550.87µs) xi-core.send.update
# removing orphan  63974893120 -> 64130591636  (+    434.51µs) xi-core.send.update
# removing orphan  64139527106 -> 64148790160  (+    476.24µs) xi-core.send.update
# removing orphan  64167844313 -> 64412020910  (+    466.21µs) xi-core.send.update
# removing orphan  64421036157 -> 64429565015  (+    458.75µs) xi-core.send.update
# removing orphan  64435860302 -> 65383281813  (+ 912501.43µs) xi-core.send.update
# removing orphan  65415720822 -> 65769075465  (+    629.63µs) xi-core.send.update
# removing orphan  65777410199 -> 65790395934  (+   1454.20µs) xi-core.send.update
# removing orphan  65880595918 -> 67376656362  (+    591.73µs) xi-core.send.update
# removing orphan  67386242240 -> 67397607648  (+    619.65µs) xi-core.send.update
# removing orphan  67401474543 -> 67676716412  (+    505.33µs) xi-core.send.update
# removing orphan  67687291608 -> 67698575401  (+    254.40µs) xi-core.send.update
# removing orphan  67701638526 -> 67837762660  (+    479.97µs) xi-core.send.update
# removing orphan  67847084869 -> 67858328897  (+    467.89µs) xi-core.send.update
# removing orphan  67868410938 -> 67890147720  (+    727.93µs) xi-core.send.update
# removing orphan  67993651424 -> 68011129646  (+   1184.68µs) xi-core.send.update
# removing orphan  68023404562 -> 68065162886  (+   1122.21µs) xi-core.send.update
# removing orphan  68132458650 -> 68145072359  (+    882.59µs) xi-core.send.update
# removing orphan  68154174380 -> 68580035631  (+    631.57µs) xi-core.send.update
# removing orphan  68593790969 -> 68606475607  (+    386.65µs) xi-core.send.update

# %% [markdown]
# # call trees
#
# These group all traces which share a common ancestor. A single trace can have multiple children; for instance `xi-core.recv.update` leads to `xi-core.send.scroll_to` _and_ `xi-core.send.update` (as well as other calls to plugins)
#
# Time deltas (+ xxx µs) are relative to the parent.

# %%
group_print(calls[1])
# Out:
# total elapsed: 383018.53µs
# 2:                     0 -> 906929       (+    906.93µs) xi-mac.send.set_theme
#  8:               906929 -> 380583042    (+ 379676.11µs) xi-core.recv.set_theme
#   10:          380583042 -> 382874127    (+   2291.09µs) xi-core.send.theme_changed
#    11:         382874127 -> 383925454    (+   1051.33µs) xi-mac.recv.theme_changed

# %%
group_print(calls[-1])
# Out:
# total elapsed: 2503.86µs
# 12835:                 0 -> 298205787605 (+   2735.64µs) xi-mac.send.request_lines
#  12836:     298205787605 -> 298206082125 (+    294.52µs) xi-core.recv.edit
#   12837:    298206082125 -> 298207798111 (+   1715.99µs) xi-core.send.update
#    12838:   298207798111 -> 298208291464 (+    493.35µs) xi-mac.recv.update

# %%
group_print(calls[-16])
# Out:
# total elapsed: 1980.03µs
# 12775:                 0 -> 298010611661 (+   3894.95µs) xi-mac.send.scroll
#  12776:     298010611661 -> 298010835364 (+    223.70µs) xi-core.recv.edit
#   12777:    298010835364 -> 298012068542 (+   1233.18µs) xi-core.send.update
#    12778:   298012068542 -> 298012591687 (+    523.14µs) xi-mac.recv.update

# %% [markdown]
# ## Event pairs (send/recv)
#
# Let's start with pairs of items: for every node, if it has a parent, add (parent, child) to some index of identifiers.

# %%
pairs = defaultdict(list)
for node in traces:
    if node.parent is not None:
        ident = "{}.{} -> {}.{}".format(node.parent.proc_name,
                                      node.parent.label,
                                      node.proc_name,
                                      node.label)
        pairs[ident].append(node)

# %% [markdown]
# ## average inter-event time
#
# For common event pairs (recv/send, send/recv) what is the average time between events for occurances of that pair?

# %%
results = []
for (k, v) in pairs.items():
    if len(v) < 5:
        continue
    times = [p.timestamp - p.parent.timestamp for p in v]
    results.append((k, times))

avgs = [(k, sum(v)/len(v)) for k, v in results]
avgs.sort(key=lambda kv: kv[1])

for i, (k, avg) in enumerate(avgs):
    print("({:<4} samples){:>10.2f} µs: {}".format(len(results[i][1]), avg/1000, k, ))
# Out:
# (3083 samples)    167.73 µs: xi-core.send.update_cmds -> xi-mac.recv.update_cmds
# (6    samples)    176.37 µs: xi-core.send.def_style -> xi-mac.recv.def_style
# (6    samples)    233.62 µs: xi-core.send.scroll_to -> xi-mac.recv.scroll_to
# (1068 samples)   1300.70 µs: xi-core.send.update -> xi-mac.recv.update
# (2460 samples)  14630.57 µs: xi-core.recv.edit -> xi-core.send.update
# (1607 samples)  22098.10 µs: xi-host.syntect.recv.update_spans -> xi-core.send.update
# (291  samples)  40617.63 µs: xi-host.syntect.recv.add_scopes -> xi-core.send.update
# (291  samples) 887673.50 µs: xi-core.recv.edit -> xi-core.send.def_style
# (309  samples)3695684.87 µs: xi-mac.send.scroll -> xi-core.recv.edit
# (309  samples)8241669.36 µs: xi-mac.send.request_lines -> xi-core.recv.edit
# (9    samples)17375749.87 µs: xi-host.syntect.send.resp -> syntect.send.update_spans
# (13   samples)17597805.73 µs: xi-host.syntect.send.resp -> syntect.send.add_scopes
# (246  samples)18503583.99 µs: syntect.send.update_spans -> xi-host.syntect.recv.update_spans
# (164  samples)19336851.76 µs: syntect.send.add_scopes -> xi-host.syntect.recv.add_scopes

# %% [markdown]
# ## As a graph:

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import column
from bokeh.models import PrintfTickFormatter
from bokeh.models import HoverTool
import colorcet as cc
import math
import random

output_notebook()

def label_for_event(event):
    par = "{}.{}".format(event.parent.proc_name, event.parent.label)
    child = "{}.{}".format(event.proc_name, event.label)
    return "{}->{}".format(par, child)



to_graph = [(label_for_event(v[0]), v) for k ,v in pairs.items() if len(v) > 5]
to_graph.sort(key=lambda kv: kv[0])
keys = [k for k,_ in to_graph]

interval = int(len(cc.rainbow) / len(to_graph))
palette = [cc.rainbow[i*interval] for i in range(len(to_graph) + 1)]

p = figure(y_range=keys, plot_width=900, plot_height=600, title="RPC time-to-receive, by route",
          toolbar_location='right')
p.xaxis[0].formatter = PrintfTickFormatter(format="%dµs")

for i, (k, v) in enumerate(to_graph):
    times = [(p.timestamp - p.parent.timestamp)/1000 for p in v]
    color = palette[i]
    cr = p.circle(times, [k]*len(times), color=color, fill_alpha=0.5, hover_alpha=1.0)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6a1daa19-1e56-40ff-8609-70cb19f6628a">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6a6737fd-8919-4f2e-9d86-85aa1aa446a3"></div>
# </div>

# %% [markdown]
# ![graph_1.png](./graph_2.png)

# %% [markdown]
# ## Send interval as a function of timestamp

# %%
def label_for_event(event):
#     par = "{}.{}".format(event.parent.proc_name, event.parent.label)
#     child = "{}.{}".format(event.proc_name, event.label)
    return "{}->{}".format(event.parent.proc_name, event.proc_name)

to_graph = [(label_for_event(v[0]), v) for k ,v in pairs.items() if len(v) > 5]
to_graph.sort(key=lambda kv: kv[0])
keys = [k for k,_ in to_graph]

max_t = traces[-1].timestamp

interval = int(len(cc.rainbow) / len(to_graph))
palette = [cc.rainbow[i*interval] for i in range(len(to_graph) + 1)]

# random.shuffle(palette)

p = figure(plot_width=900, plot_height=700,
           title="RPC send time to response lag",
          toolbar_location='right')

shapes = [p.circle, p.square, p.cross, p.diamond, p.asterisk, p.triangle]
p.yaxis[0].formatter = PrintfTickFormatter(format="%dms")
p.xaxis[0].formatter = PrintfTickFormatter(format="%dms")
p.xaxis.axis_label = "event time"
p.yaxis.axis_label = "response delay"

for i, (k, v) in enumerate(to_graph):
    durations = [(p.timestamp - p.parent.timestamp)/1000000 for p in v]
    timestamps = [p.timestamp / 1000000 for p in v]
    color = palette[i]
    f = shapes[i % len(shapes)]
    cr = f(timestamps, durations, color=color, fill_alpha=0.5, legend=k)

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="68c3032c-71d3-4d7f-9427-4d3c8961950a"></div>
# </div>

# %% [markdown]
# That doesn't tell us _too_ much. Over this small trace, we can glean a bit of interesting stuff:
#
# - The syntect plugin is frequently responding quickly;
# - the longest average operation is between receiving an update in core and updating plugins
# - xi-mac takes significantly longer to process `scroll_to` than to process `update`
